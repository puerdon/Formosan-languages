# %%
import streamlit as st
import pandas as pd
from docx import Document

st.markdown("# 上傳語料")

uploaded_file = st.file_uploader("Choose a file")
if uploaded_file is not None:
    # 读取 DOCX 文件
    doc = Document(uploaded_file)

    # 将内容提取并显示
    st.write("**文档内容:**")
    for paragraph in doc.paragraphs:
        st.write(paragraph.text)

    # 显示段落数
    st.write(f"总段落数: {len(doc.paragraphs)}")

# # CSS to inject contained in a string
# hide_table_row_index = """
#             <style>
#             thead tr th:first-child {display:none}
#             tbody th {display:none}
#             </style>
#             """

# # Inject CSS with Markdown
# st.markdown(hide_table_row_index, unsafe_allow_html=True)


# # Cache the raw data and profile report to speed up subseuqent requests
# @st.cache_data
# def get_basic_stats():
#     d = pd.read_pickle(
#         'data/stats_of_each_text_20230321.pkl', compression="gzip")
#     return d


# @st.cache_data
# def get_each_text_stats():
#     d = pd.read_pickle(
#         'data/stats_of_each_text_with_subtext_20221228-3.pkl', compression="gzip")
#     return d


# df_basic_stats = get_basic_stats()

# each_text_with_stories = get_each_text_stats()

# st.markdown("## 各篇文本詞句數統計")

# st.table(df_basic_stats)

# st.markdown("## 含單篇子文本的詞句數統計")

# st.table(each_text_with_stories)

# %%
import re
from docx import Document
import pandas as pd
def parse_docx(file_path):
    # 读取 .docx 文件
    doc = Document(file_path)
    text = "\n".join([p.text for p in doc.paragraphs])+'\n'  # 合并所有段落为文本

    # 定义正则模式
    pattern = r"(A|RA|G|M|RM|E|RE):\s*(.*?)\n"
    matches = re.findall(pattern, text)
    
    # 按段落类型组织内容
    parsed_data = {}
    for key, value in matches:

        if key not in parsed_data:
            parsed_data[key] = []
        parsed_data[key].append(value.strip())
    
    return pd.DataFrame.from_dict(parsed_data)



# 示例调用
file_path = "1.docx"  # 替换为您的文件路径
parsed_data = parse_docx(file_path)

print(parsed_data)
# Out:
#                                                     A    RA     G  \
# 0   izua ka tintal tia mareDava , “ ari , ta kivaL...  none  none
# 1                               vaik a kivaLa tiamadu  none  none
# 2                  “ vuvu , vuvu , ” aya tia mareDava  none  none
# 3                     “ kemuda ” aya ti sa vuLuvuLung  none  none
# 4    “ kivaLa amen vuvu , tanusun ” aya a za mareDava  none  none
# 5                 “ pai tuma’u ” aya ti sa vuLuvuLung  none  none
# 6   ka tuma’ tia mareDava pacun tua za ’acang sema...  none  none
# 7   “ vuvu , pai ta culuaw sa su’acang , ki men a ...  none  none
# 8            “ pa’uLi’uLid mun ” aya ti sa vuLuvuLung  none  none
# 9   “ wui , vuvu , a nema nia siveca tanusun ” aya...  none  none
# 10  “ ki men a maisu tua ta ’avay , ki sun a cemul...  none  none
# 11            “ uwi , numaya ” (a)ya za ti vuLuvuLung  none  none
# 12  demame’ ti sa vuLuvuLung ta za ’acang , sa len...  none  none
# 13  ka lemenglengis ti sa vuLuvuLung , semuLavuLav...  none  none
# 14  ka penceracerak ti sa vuLuvuLung , ’emu’emuang...  none  none
# 15  pai ka makaceperakanga ti vuLuvuLung , maka’em...  none  none
# 16  “ a za dapal , a za ’avuvung , a za ’avay , vu...  none  none
# 17                          “ uwi ” aya ti vuLuvuLung  none  none
# 18  “ uri vaik amen a makakucu a semazuaikaluvuluv...  none  none
# 19                          “ uwi ” aya ti vuLuvuLung  none  none
# 20         makakucukucu tia mareDava sa pasa vaLangai  none  none
# 21  “ nu ’ivu ti vuLuvuLung Di , “ nge ” ayau Di ”...  none  none
# 22  aLapen nia mareDava za piniyapaling ni vuLuvuL...  none  none
# 23  “ lamareDava ” aya ti vuLuvuLung “ nge ” aya z...  none  none
# 24  “ lamareDava , kemudakuda mun ” aya ti vuLuvuL...  none  none
# 25  “ ’aku nu ’ivu aken “ nge ” aya za mareDava . ...  none  none
# 26                 casaw ti vuLuvuLung neka nu caucau  none  none
# 27  “ lamareDava ” aya ti vuLuvuLung “ nge ” aya z...  none  none
# 28  pacun a pasa vaLanga , manu kucu a migilegilei...  none  none
# 29  “ manu tima amun a temeveLaveLa tanuaken ” aya...  none  none
# 30        sa aLapi a zua ’aseLu sa tu’etu’i a za kucu  none  none
# 31  pai kemelanganga ti vuLuvuLung tu vaikanga tia...  none  none
# 32  pacunananga za kinisumavan nimadu a ’avay a vutul  none  none
# 33  “ vaikanga tia mareDava , ku kitaviLilaw ” aya...  none  none
# 34                     manu temluteluanga ta za pana’  none  none
# 35  “ la mareDava , kalavau aken ” aya ti vuLuvuLu...  none  none
# 36  “ uwi , uwi ” aya tia mareDava , “ kelu , kiri...  none  none
# 37     ka telavin a za mareDava , puisi’an a za zalum  none  none
# 38  nu (u)ri temelu’ ti vuLuvuLung maculu sa zalum...  none  none
# 39  “ la mareDava , ’aku nu temelu’ aken maculu sa...  none  none
# 40  “ a inu a maculuculu , ’aku sun a venecaveca (...  none  none
# 41            “ maculu , maculu ” aya ti vuLuvuLung .  none  none
# 42     nu (u)ri temelu’ ti vuLuvuLung maculu sakamaya  none  none
# 43  “ vaik amen numaya , nu ika sun a makaya temel...  none  none
# 44                          manu madudu ti vuLuvuLung  none  none
# 45  “ kana ku ’inatucu ” aya ti vuLuvuLung sa pata...  none  none
#
#                                             M    RM
# 0              有一次，有兩個彼此是朋友的女孩說：「走，我們去找老爺爺玩。」  none
# 1                               他們就去（找老爺爺）玩了。  none
# 2                                「爺爺，爺爺」女孩們說。  none
# 3                                 「做什麼呀？」老人說。  none
# 4                        「我們來找爺爺，您，玩啊！」那些女孩說。  none
# 5                                  「進來吧！」老人說。  none
# 6                         當女孩們進屋時，看到那頭豬到籬笆上面。  none
# 7                「爺爺，那咱們來殺您的豬，我們要暫住您這裡。」女孩們說。  none
# 8                             「妳們說的是真的嗎？」老人說。  none
# 9                       「是啊！爺爺，我們騙您什麼呢！」女孩們說。  none
# 10                        「我們來搗米做咱們的米糕，您去殺豬！」  none
# 11                                    「好」老人說。  none
# 12                                 老人就捉豬，烤豬毛。  none
# 13                          當老人烤豬毛時，女孩們就除去米糠。  none
# 14                            當老人剖開豬時，女孩們就磨粉。  none
# 15                當老人剖開好了豬，女孩們也磨好粉了，他們就開始做米糕。  none
# 16                    「爺爺，您把腿，內臟，米糕放在門外」女孩們說。  none
# 17                                    「好」老人說。  none
# 18                         「我們要去庭院互相抓頭蝨」女孩們說。  none
# 19                                    「好」老人說。  none
# 20                          那些女孩互相抓到頭蝨，就往舂裏放。  none
# 21               「如果爺爺叫我們，你們就說：『嗯』！」女孩們（對蝨子）說  none
# 22             女孩們拿走爺爺放在門邊的好吃的肉以及內臟，然後他們就離開了。  none
# 23             老人喊著：「小女孩們呀！」，就聽到傳來的回答聲說：「嗯！」。  none
# 24       老人（又）喊著：「小女孩們呀！妳們在做什麼？」蝨子（又回答）說：「嗯！」  none
# 25  老人（想）：「為什麼當我喊他們時，那些女孩們（總是）回答：『嗯！』，我去看看吧！」  none
# 26                                老人出去一看，沒有人。  none
# 27          老人（又）喊著：「小女孩們呀！」在舂那裏（有聲音回答）說：『嗯！』  none
# 28                         往舂裏一看，原來是一堆在蠕動的頭蝨。  none
# 29                           「原來是你們在回答我。」老人說。  none
# 30                              然後就拿了杵，把蝨子剁碎。  none
# 31                                老人知道女孩們已走了。  none
# 32                         （他再去）看了那些他所烹調的米糕和肉  none
# 33          「女孩們已走了，我要去追（他們）。」說完，拿了佩刀，就用跑的去了。  none
# 34                               結果（他們）已在涉水過河  none
# 35                          老人喊著：「小女孩們呀！等等我。」  none
# 36              女孩們（回答）說：「好，好」「來啊！快點！」女孩們（又）說  none
# 37                          當那些女孩們一上岸，就在水裏小便。  none
# 38                      當老人要涉水（過河），水很熱，像滾燙的水。  none
# 39          「小女孩們呀！為什麼當我過河，水很熱，而妳們怎麼過河的？」老人說。  none
# 40                       「哪裏會燙！你為什麼說話騙人」女孩們說。  none
# 41                                 「燙！燙！」老人說。  none
# 42                          當老人要涉水（過河），水還是很熱。  none
# 43            「如果你不能涉水（過河），我們就要走了」女孩們說，然後就走了。  none
# 44                                  結果老人（很）生氣  none
# 45              「早知道我就非禮（妳們）」老人說。然後就拿石頭往巨石上剁。  none

# %%
for a in parsed_data:
    print(a)
    print(len(parsed_data[a]))
# Out:
# A
# 46
# RA
# 46
# G
# 46
# M
# 46
# RM
# 46
